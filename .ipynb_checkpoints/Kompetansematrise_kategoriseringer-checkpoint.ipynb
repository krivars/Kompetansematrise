# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import csv
import re

from sklearn import metrics
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import AffinityPropagation

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Parametere

# %%
n_clusters=5
#type='Interesse' 
type='Kompetanse' 
#type='Kombinert'

# %% [markdown]
# ### Funksjoner

# %%
def group_variables(df, cats):
    
    ucats = set([])
    col2cat = {}
    with open('Kategorier kompetanse og interesser.csv', 'r') as f:
        reader = csv.reader(f, delimiter=';')
        next(reader, None)
        for row in reader:
            col2cat[row[0]] = {'Kategori': row[1], 'Underkategori': row[2]}
            ucats.add(row[2])
    
    dfc = df.reset_index()[['Navn', 'Team']]
    for ucat in ucats:
        col_subset = np.matrix(df[[col for col in df.columns if col2cat[col]['Underkategori'] == ucat]])
        dfc_add = pd.DataFrame(col_subset.sum(1)/col_subset.shape[1], columns=[ucat])
        dfc = pd.concat([dfc, dfc_add], axis=1)
        
    dfc.set_index(['Navn','Team'],inplace=True)
        
    return dfc

def do_pca(df):
    pca = PCA(n_components=2)
    dfs = preprocessing.scale(ndf,with_std=False)
    pca.fit(dfs)
    transformed_df = pca.transform(dfs)
    newdf = pd.concat([df.reset_index()[['Navn', 'Team']], pd.DataFrame(transformed_df)], axis=1)
    components = pd.concat([df.transpose().reset_index()['index'], pd.DataFrame({'1':pca.components_[0]}), pd.DataFrame({'2':pca.components_[1]})], axis=1).set_index('index')
    return newdf, components


def plot_pca(df):
    ms = 90
    ax = df[df['Team']=='IM'].plot(kind='scatter', x=0, y=1, s=ms, color='b', label='IM', figsize=(12,12))
    df[df['Team']=='BST' ].plot(kind='scatter', x=0, y=1, s=ms, color='r', label='BST', ax=ax)
    df[df['Team']=='ITST'].plot(kind='scatter', x=0, y=1, s=ms, color='y', label='ITST', ax=ax)

    for navn, team, x, y in df.values:
        if team == 'IM':
            horz = 'right'
        else:
            horz = 'left'
        shortname = re.match('([A-Za-z]+)\,?', navn).group(1)
        plt.annotate(shortname, xy=(x, y), textcoords = 'offset points', xytext = (0,8), horizontalalignment = horz)
    
    plt.title('PCA-analyse av %s' % type)
    pass

def plot_component(components, ind):
    
    a = max(abs(components[str(ind)]))
    
    plt.figure()
    components.sort(str(ind))[str(ind)].plot(kind='barh', xlim=(-1.1*a,1.1*a), figsize=(8,10), title='PCA component ' + str(ind));

    pass

def plot_most_component(components, ind):
    
    a = max(abs(components[str(ind)]))
    
    plt.figure()
    components_sorted = components.sort(str(ind))[str(ind)]
    subset = pd.concat([components_sorted[:3],components_sorted[-3:]])
    subset.plot(kind='barh', xlim=(-1.1*a,1.1*a), figsize=(8,6), title='PCA component ' + str(ind));

    pass


def plot_component_new(components, ind):
    components_im = components[components['Kategori']=='IM']
    components_bst = components[components['Kategori']=='BST']
    components_itst = components[components['Kategori']=='ITST']
    components_tverr = components[components['Kategori']=='Tverrfaglige kompetanser ']

    fig = plt.figure(figsize=(25,25))

    axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)print()

    p1 = plt.barh(components_im.index, components_im.sort(str(ind))[str(ind)], left=0, color='b')
    p2 = plt.barh(components_bst.index, components_bst.sort(str(ind))[str(ind)], left=0,color='r')
    p3 = plt.barh(components_itst.index, components_itst.sort(str(ind))[str(ind)], left=0,color='g')
    if(type=='Kombinert' or type=='Kompetanse'):
        p4 = plt.barh(components_tverr.index, components_tverr.sort(str(ind))[str(ind)], left=0,color='y')

    axes.set_yticks(components.index)
    axes.set_yticklabels(components['index'], figure=fig, size=20)
    
    plt.title('PCA-komponent %d for analyse av %s' % (ind,type))
    
    plt.show()
    pass

# %% [markdown]
# ### Datasett

# %%
df = pd.io.parsers.read_csv(type+"_formatert.csv", sep=';', index_col=[0,1])
df.dropna(how='any', inplace=True)

cats = pd.io.parsers.read_csv('Kategorier kompetanse og interesser.csv', sep=';')

ndf = group_variables(df, cats)

# %% [markdown]
# ### PCA-analyse

# %%
newdf, components = do_pca(ndf)

# %%
plot_pca(newdf)

## Hent inn kategorier per kompetanse/interesse
#kompetanse_type= pd.io.parsers.read_csv('Kategorier kompetanse og interesser.csv', sep=';', header=0, usecols=[1])
#interesse_type= pd.io.parsers.read_csv('Kategorier kompetanse og interesser.csv', sep=';', header=None, usecols=[1], skiprows=33)
#interesse_type.columns=['Kategori']
#kombinert_type = pd.concat([kompetanse_type,interesse_type], axis=0, ignore_index=True)
#
#if type=='Kompetanse':
#    feature_type=kompetanse_type
#elif type=='Interesse':
#    feature_type = interesse_type
#else:
#    feature_type = kombinert_type
#
#components.reset_index(inplace=True)
#components = pd.concat([components, feature_type], axis=1)
#
#
plot_most_component(components,1)
plot_most_component(components,2)

# %%
ndf
# Out:
#                             Prossessforbedring  Salg/relasjonsbygging  \
# Navn                  Team
# Aanonsen, Tor         IM              2.000000               2.500000
# Axelsen, Vebjorn      IM              2.333333               3.500000
# Berisha, Arber        IM              1.000000               2.333333
# Botnen, Martin        IM              1.333333               3.166667
# Ehrndal, Marcus       IM              2.666667               3.333333
# Fladmark, Baste       IM              2.333333               1.500000
# Gaze, Kevin           IM              1.000000               2.000000
# Glaeserud, Pia        IM              2.333333               2.333333
# Henrichsen, Kristian  IM              3.000000               2.500000
# Holmestad, Ola        IM              1.333333               2.333333
# Ivarsoy, Kristine     IM              1.000000               1.166667
# Jorgensen, Morten     IM              1.333333               2.666667
# Krogvig, Lars         IM              1.000000               1.500000
# Larsson, Patrik       IM              2.000000               1.500000
# Lohne, Erik           IM              2.666667               3.166667
# Mortensen, Maria      IM              1.000000               1.333333
# Nygaard, Linn         IM              1.333333               1.833333
# Olsen, Elin           IM              1.333333               1.500000
# Paulsen, Vegar        IM              2.333333               3.666667
# Reidulff, Mari        IM              1.000000               1.000000
# Sunde, Torstein       IM              1.666667               2.166667
# Tokheim, Stian        IM              1.000000               2.166667
# Tveit, Henrik         IM              1.000000               1.333333
# Kragerud, Rolf        BST             2.333333               4.500000
# Overrein, Erik        BST             2.666667               4.166667
# Elstad, Ole-Christian BST             3.333333               3.500000
# Haavik, Ola           BST             2.333333               3.500000
# Oysaed, Jostein       BST             2.000000               2.333333
# Viklander, Jonathan   BST             3.000000               1.500000
# Strand, Brage         BST             2.000000               2.000000
# Angset C., Lise       BST             1.000000               1.000000
# Jahren, Kristin       BST             1.666667               1.333333
# Landstad, Kari        BST             1.666667               1.333333
# Thorne, Wilhelm       BST             1.000000               1.166667
# Thylin, Katarina      BST             3.000000               1.666667
# Kristensen, Veronica  BST             1.666667               1.166667
# Klemsdal, Ragnhild    BST             1.333333               1.166667
# Holte, Tormod         ITST            2.666667               4.333333
# bg                    ITST            3.000000               3.000000
# Alnes, Morten         ITST            4.000000               3.666667
# Pedersen, Geir        ITST            2.000000               4.333333
# Elverum, Tor          ITST            2.000000               2.666667
# Lindberg, Emma        ITST            1.333333               2.333333
# Holstad, Mads         ITST            3.000000               2.000000
# Hermansen, Thomas     ITST            2.000000               1.500000
# Sandstrom, Anton      ITST            2.666667               1.666667
# Rode, William         ITST            2.000000               1.500000
# Havro, Lars           ITST            1.666667               1.500000
# Rystad, Kristina      ITST            2.000000               1.333333
# Gussis, Gunnhild      ITST            3.333333               3.333333
# Korsen, Eirik Hamre   BST             5.000000               4.333333
#
#                             IT-Governance  Effektiv kommunikasjon  \
# Navn                  Team
# Aanonsen, Tor         IM              2.0                     3.0
# Axelsen, Vebjorn      IM              2.5                     4.0
# Berisha, Arber        IM              1.0                     3.2
# Botnen, Martin        IM              2.5                     3.8
# Ehrndal, Marcus       IM              2.0                     3.8
# Fladmark, Baste       IM              2.5                     2.0
# Gaze, Kevin           IM              1.0                     3.0
# Glaeserud, Pia        IM              2.0                     3.2
# Henrichsen, Kristian  IM              2.5                     3.2
# Holmestad, Ola        IM              1.0                     3.6
# Ivarsoy, Kristine     IM              1.0                     1.8
# Jorgensen, Morten     IM              2.0                     3.6
# Krogvig, Lars         IM              1.0                     2.0
# Larsson, Patrik       IM              1.5                     2.2
# Lohne, Erik           IM              2.5                     3.4
# Mortensen, Maria      IM              1.0                     2.0
# Nygaard, Linn         IM              1.0                     3.2
# Olsen, Elin           IM              1.0                     2.2
# Paulsen, Vegar        IM              2.5                     3.6
# Reidulff, Mari        IM              1.0                     1.8
# Sunde, Torstein       IM              1.5                     3.0
# Tokheim, Stian        IM              1.0                     3.8
# Tveit, Henrik         IM              1.0                     2.4
# Kragerud, Rolf        BST             2.0                     4.8
# Overrein, Erik        BST             3.0                     3.4
# Elstad, Ole-Christian BST             1.5                     4.0
# Haavik, Ola           BST             3.0                     4.6
# Oysaed, Jostein       BST             3.0                     3.0
# Viklander, Jonathan   BST             1.0                     2.4
# Strand, Brage         BST             1.0                     2.6
# Angset C., Lise       BST             1.0                     1.8
# Jahren, Kristin       BST             1.0                     2.2
# Landstad, Kari        BST             1.0                     2.4
# Thorne, Wilhelm       BST             1.0                     2.0
# Thylin, Katarina      BST             1.0                     2.2
# Kristensen, Veronica  BST             1.0                     1.8
# Klemsdal, Ragnhild    BST             1.0                     1.8
# Holte, Tormod         ITST            2.5                     4.0
# bg                    ITST            3.5                     3.4
# Alnes, Morten         ITST            4.0                     3.8
# Pedersen, Geir        ITST            2.0                     3.2
# Elverum, Tor          ITST            2.0                     3.4
# Lindberg, Emma        ITST            1.0                     3.2
# Holstad, Mads         ITST            2.0                     2.6
# Hermansen, Thomas     ITST            1.0                     3.0
# Sandstrom, Anton      ITST            1.0                     2.8
# Rode, William         ITST            1.0                     2.4
# Havro, Lars           ITST            1.0                     2.4
# Rystad, Kristina      ITST            1.0                     2.2
# Gussis, Gunnhild      ITST            2.0                     4.0
# Korsen, Eirik Hamre   BST             4.0                     4.0
#
#                             Business Intelligence  \
# Navn                  Team
# Aanonsen, Tor         IM                     2.00
# Axelsen, Vebjorn      IM                     3.50
# Berisha, Arber        IM                     2.25
# Botnen, Martin        IM                     4.00
# Ehrndal, Marcus       IM                     3.00
# Fladmark, Baste       IM                     2.25
# Gaze, Kevin           IM                     1.75
# Glaeserud, Pia        IM                     3.50
# Henrichsen, Kristian  IM                     2.75
# Holmestad, Ola        IM                     3.00
# Ivarsoy, Kristine     IM                     1.25
# Jorgensen, Morten     IM                     3.50
# Krogvig, Lars         IM                     1.25
# Larsson, Patrik       IM                     2.25
# Lohne, Erik           IM                     3.25
# Mortensen, Maria      IM                     1.75
# Nygaard, Linn         IM                     3.50
# Olsen, Elin           IM                     1.75
# Paulsen, Vegar        IM                     2.50
# Reidulff, Mari        IM                     1.00
# Sunde, Torstein       IM                     3.25
# Tokheim, Stian        IM                     1.75
# Tveit, Henrik         IM                     1.00
# Kragerud, Rolf        BST                    2.75
# Overrein, Erik        BST                    3.50
# Elstad, Ole-Christian BST                    2.25
# Haavik, Ola           BST                    2.50
# Oysaed, Jostein       BST                    2.00
# Viklander, Jonathan   BST                    1.25
# Strand, Brage         BST                    1.00
# Angset C., Lise       BST                    1.00
# Jahren, Kristin       BST                    1.00
# Landstad, Kari        BST                    1.00
# Thorne, Wilhelm       BST                    1.00
# Thylin, Katarina      BST                    1.75
# Kristensen, Veronica  BST                    1.00
# Klemsdal, Ragnhild    BST                    1.00
# Holte, Tormod         ITST                   1.50
# bg                    ITST                   1.00
# Alnes, Morten         ITST                   3.00
# Pedersen, Geir        ITST                   1.25
# Elverum, Tor          ITST                   1.00
# Lindberg, Emma        ITST                   1.00
# Holstad, Mads         ITST                   3.00
# Hermansen, Thomas     ITST                   1.00
# Sandstrom, Anton      ITST                   1.00
# Rode, William         ITST                   1.00
# Havro, Lars           ITST                   1.00
# Rystad, Kristina      ITST                   1.00
# Gussis, Gunnhild      ITST                   1.00
# Korsen, Eirik Hamre   BST                    4.25
#
#                             Basic IT verktoey og IT forstaelse  \
# Navn                  Team
# Aanonsen, Tor         IM                                   4.0
# Axelsen, Vebjorn      IM                                   4.5
# Berisha, Arber        IM                                   4.0
# Botnen, Martin        IM                                   4.5
# Ehrndal, Marcus       IM                                   4.5
# Fladmark, Baste       IM                                   4.0
# Gaze, Kevin           IM                                   3.0
# Glaeserud, Pia        IM                                   3.5
# Henrichsen, Kristian  IM                                   4.0
# Holmestad, Ola        IM                                   4.0
# Ivarsoy, Kristine     IM                                   2.0
# Jorgensen, Morten     IM                                   4.0
# Krogvig, Lars         IM                                   2.0
# Larsson, Patrik       IM                                   3.0
# Lohne, Erik           IM                                   4.5
# Mortensen, Maria      IM                                   2.0
# Nygaard, Linn         IM                                   4.5
# Olsen, Elin           IM                                   3.0
# Paulsen, Vegar        IM                                   4.0
# Reidulff, Mari        IM                                   2.0
# Sunde, Torstein       IM                                   3.5
# Tokheim, Stian        IM                                   4.5
# Tveit, Henrik         IM                                   2.0
# Kragerud, Rolf        BST                                  4.5
# Overrein, Erik        BST                                  4.5
# Elstad, Ole-Christian BST                                  4.0
# Haavik, Ola           BST                                  5.0
# Oysaed, Jostein       BST                                  5.0
# Viklander, Jonathan   BST                                  4.5
# Strand, Brage         BST                                  2.5
# Angset C., Lise       BST                                  1.5
# Jahren, Kristin       BST                                  2.5
# Landstad, Kari        BST                                  3.0
# Thorne, Wilhelm       BST                                  2.5
# Thylin, Katarina      BST                                  4.0
# Kristensen, Veronica  BST                                  1.5
# Klemsdal, Ragnhild    BST                                  2.0
# Holte, Tormod         ITST                                 4.5
# bg                    ITST                                 4.0
# Alnes, Morten         ITST                                 5.0
# Pedersen, Geir        ITST                                 4.5
# Elverum, Tor          ITST                                 3.0
# Lindberg, Emma        ITST                                 3.5
# Holstad, Mads         ITST                                 3.0
# Hermansen, Thomas     ITST                                 3.5
# Sandstrom, Anton      ITST                                 3.5
# Rode, William         ITST                                 3.5
# Havro, Lars           ITST                                 3.0
# Rystad, Kristina      ITST                                 2.5
# Gussis, Gunnhild      ITST                                 2.5
# Korsen, Eirik Hamre   BST                                  4.0
#
#                             Master Data Management  IT-Assessment  \
# Navn                  Team
# Aanonsen, Tor         IM                      2.00           1.00
# Axelsen, Vebjorn      IM                      3.25           2.75
# Berisha, Arber        IM                      1.75           1.00
# Botnen, Martin        IM                      3.00           1.75
# Ehrndal, Marcus       IM                      3.50           1.00
# Fladmark, Baste       IM                      1.25           1.75
# Gaze, Kevin           IM                      2.25           1.00
# Glaeserud, Pia        IM                      2.00           1.00
# Henrichsen, Kristian  IM                      2.25           3.00
# Holmestad, Ola        IM                      2.00           1.00
# Ivarsoy, Kristine     IM                      1.00           1.00
# Jorgensen, Morten     IM                      2.75           1.00
# Krogvig, Lars         IM                      1.75           1.00
# Larsson, Patrik       IM                      1.25           1.75
# Lohne, Erik           IM                      3.25           2.75
# Mortensen, Maria      IM                      1.00           1.00
# Nygaard, Linn         IM                      1.75           1.25
# Olsen, Elin           IM                      1.50           1.50
# Paulsen, Vegar        IM                      2.00           3.00
# Reidulff, Mari        IM                      1.00           1.00
# Sunde, Torstein       IM                      2.00           1.50
# Tokheim, Stian        IM                      1.75           1.00
# Tveit, Henrik         IM                      1.50           1.00
# Kragerud, Rolf        BST                     1.00           1.25
# Overrein, Erik        BST                     3.50           3.50
# Elstad, Ole-Christian BST                     2.50           3.00
# Haavik, Ola           BST                     1.75           1.00
# Oysaed, Jostein       BST                     1.50           1.75
# Viklander, Jonathan   BST                     1.00           1.00
# Strand, Brage         BST                     2.00           1.25
# Angset C., Lise       BST                     1.00           1.00
# Jahren, Kristin       BST                     1.00           1.00
# Landstad, Kari        BST                     1.00           1.00
# Thorne, Wilhelm       BST                     1.00           1.00
# Thylin, Katarina      BST                     1.25           1.00
# Kristensen, Veronica  BST                     1.00           1.00
# Klemsdal, Ragnhild    BST                     1.00           1.00
# Holte, Tormod         ITST                    2.50           3.75
# bg                    ITST                    1.00           2.50
# Alnes, Morten         ITST                    3.50           3.50
# Pedersen, Geir        ITST                    2.00           1.75
# Elverum, Tor          ITST                    1.50           1.25
# Lindberg, Emma        ITST                    1.50           2.00
# Holstad, Mads         ITST                    1.50           1.25
# Hermansen, Thomas     ITST                    1.25           1.25
# Sandstrom, Anton      ITST                    1.25           1.50
# Rode, William         ITST                    1.25           1.50
# Havro, Lars           ITST                    1.00           1.25
# Rystad, Kristina      ITST                    1.25           1.25
# Gussis, Gunnhild      ITST                    1.25           1.00
# Korsen, Eirik Hamre   BST                     1.75           1.50
#
#                             IT-Strategi  Strategi     ...       \
# Navn                  Team                            ...
# Aanonsen, Tor         IM       1.000000      2.00     ...
# Axelsen, Vebjorn      IM       2.333333      2.75     ...
# Berisha, Arber        IM       1.000000      1.50     ...
# Botnen, Martin        IM       2.000000      2.25     ...
# Ehrndal, Marcus       IM       1.000000      2.25     ...
# Fladmark, Baste       IM       1.000000      2.75     ...
# Gaze, Kevin           IM       1.000000      1.00     ...
# Glaeserud, Pia        IM       1.000000      2.50     ...
# Henrichsen, Kristian  IM       2.000000      3.75     ...
# Holmestad, Ola        IM       1.000000      1.25     ...
# Ivarsoy, Kristine     IM       1.000000      1.75     ...
# Jorgensen, Morten     IM       1.000000      1.00     ...
# Krogvig, Lars         IM       1.000000      1.50     ...
# Larsson, Patrik       IM       1.000000      2.00     ...
# Lohne, Erik           IM       2.000000      2.25     ...
# Mortensen, Maria      IM       1.000000      1.25     ...
# Nygaard, Linn         IM       1.333333      1.50     ...
# Olsen, Elin           IM       1.000000      1.00     ...
# Paulsen, Vegar        IM       2.333333      2.25     ...
# Reidulff, Mari        IM       1.000000      1.00     ...
# Sunde, Torstein       IM       1.000000      1.00     ...
# Tokheim, Stian        IM       1.000000      1.25     ...
# Tveit, Henrik         IM       1.000000      1.00     ...
# Kragerud, Rolf        BST      1.333333      3.50     ...
# Overrein, Erik        BST      4.000000      2.50     ...
# Elstad, Ole-Christian BST      3.000000      3.50     ...
# Haavik, Ola           BST      2.000000      3.25     ...
# Oysaed, Jostein       BST      2.333333      3.50     ...
# Viklander, Jonathan   BST      1.000000      2.00     ...
# Strand, Brage         BST      1.000000      2.00     ...
# Angset C., Lise       BST      1.000000      1.50     ...
# Jahren, Kristin       BST      1.000000      2.00     ...
# Landstad, Kari        BST      1.000000      2.25     ...
# Thorne, Wilhelm       BST      1.000000      1.75     ...
# Thylin, Katarina      BST      1.000000      2.25     ...
# Kristensen, Veronica  BST      1.000000      2.00     ...
# Klemsdal, Ragnhild    BST      1.000000      1.75     ...
# Holte, Tormod         ITST     3.333333      1.25     ...
# bg                    ITST     2.666667      2.25     ...
# Alnes, Morten         ITST     3.666667      3.75     ...
# Pedersen, Geir        ITST     2.333333      1.00     ...
# Elverum, Tor          ITST     2.666667      1.75     ...
# Lindberg, Emma        ITST     1.333333      1.75     ...
# Holstad, Mads         ITST     1.666667      2.25     ...
# Hermansen, Thomas     ITST     1.000000      1.50     ...
# Sandstrom, Anton      ITST     1.000000      2.00     ...
# Rode, William         ITST     1.666667      1.50     ...
# Havro, Lars           ITST     1.000000      1.50     ...
# Rystad, Kristina      ITST     1.333333      1.25     ...
# Gussis, Gunnhild      ITST     1.666667      2.25     ...
# Korsen, Eirik Hamre   BST      1.000000      4.00     ...
#
#                             Grunnleggende kjernekompetanser (Core)  \
# Navn                  Team
# Aanonsen, Tor         IM                                  3.000000
# Axelsen, Vebjorn      IM                                  3.571429
# Berisha, Arber        IM                                  3.285714
# Botnen, Martin        IM                                  3.571429
# Ehrndal, Marcus       IM                                  3.857143
# Fladmark, Baste       IM                                  2.428571
# Gaze, Kevin           IM                                  2.857143
# Glaeserud, Pia        IM                                  3.142857
# Henrichsen, Kristian  IM                                  3.428571
# Holmestad, Ola        IM                                  2.857143
# Ivarsoy, Kristine     IM                                  1.571429
# Jorgensen, Morten     IM                                  3.285714
# Krogvig, Lars         IM                                  1.571429
# Larsson, Patrik       IM                                  1.857143
# Lohne, Erik           IM                                  3.857143
# Mortensen, Maria      IM                                  1.714286
# Nygaard, Linn         IM                                  2.857143
# Olsen, Elin           IM                                  2.142857
# Paulsen, Vegar        IM                                  3.857143
# Reidulff, Mari        IM                                  1.142857
# Sunde, Torstein       IM                                  2.142857
# Tokheim, Stian        IM                                  2.571429
# Tveit, Henrik         IM                                  1.428571
# Kragerud, Rolf        BST                                 4.428571
# Overrein, Erik        BST                                 3.857143
# Elstad, Ole-Christian BST                                 4.000000
# Haavik, Ola           BST                                 4.000000
# Oysaed, Jostein       BST                                 3.000000
# Viklander, Jonathan   BST                                 2.285714
# Strand, Brage         BST                                 2.571429
# Angset C., Lise       BST                                 1.714286
# Jahren, Kristin       BST                                 2.000000
# Landstad, Kari        BST                                 1.714286
# Thorne, Wilhelm       BST                                 1.714286
# Thylin, Katarina      BST                                 2.428571
# Kristensen, Veronica  BST                                 1.428571
# Klemsdal, Ragnhild    BST                                 1.285714
# Holte, Tormod         ITST                                3.285714
# bg                    ITST                                3.571429
# Alnes, Morten         ITST                                3.857143
# Pedersen, Geir        ITST                                3.000000
# Elverum, Tor          ITST                                3.142857
# Lindberg, Emma        ITST                                3.000000
# Holstad, Mads         ITST                                2.571429
# Hermansen, Thomas     ITST                                2.428571
# Sandstrom, Anton      ITST                                2.571429
# Rode, William         ITST                                2.285714
# Havro, Lars           ITST                                2.142857
# Rystad, Kristina      ITST                                2.000000
# Gussis, Gunnhild      ITST                                3.857143
# Korsen, Eirik Hamre   BST                                 4.571429
#
#                             IT-Anskaffelse  Supply Chain  IM Felles  \
# Navn                  Team
# Aanonsen, Tor         IM          1.428571      1.166667   4.000000
# Axelsen, Vebjorn      IM          2.714286      1.000000   5.000000
# Berisha, Arber        IM          1.142857      1.333333   3.666667
# Botnen, Martin        IM          2.285714      1.000000   5.000000
# Ehrndal, Marcus       IM          2.285714      2.333333   4.333333
# Fladmark, Baste       IM          1.714286      2.666667   2.666667
# Gaze, Kevin           IM          1.571429      1.333333   3.666667
# Glaeserud, Pia        IM          1.714286      2.166667   3.000000
# Henrichsen, Kristian  IM          2.428571      3.000000   4.333333
# Holmestad, Ola        IM          1.714286      1.000000   4.333333
# Ivarsoy, Kristine     IM          1.000000      1.333333   2.000000
# Jorgensen, Morten     IM          1.714286      1.833333   3.666667
# Krogvig, Lars         IM          1.000000      1.000000   2.333333
# Larsson, Patrik       IM          1.571429      1.666667   3.000000
# Lohne, Erik           IM          3.142857      1.500000   4.000000
# Mortensen, Maria      IM          1.000000      1.000000   2.666667
# Nygaard, Linn         IM          1.571429      1.000000   4.666667
# Olsen, Elin           IM          1.285714      1.000000   2.333333
# Paulsen, Vegar        IM          3.000000      3.000000   3.000000
# Reidulff, Mari        IM          1.000000      1.000000   1.000000
# Sunde, Torstein       IM          1.428571      1.000000   3.333333
# Tokheim, Stian        IM          1.142857      1.000000   3.666667
# Tveit, Henrik         IM          1.000000      1.000000   2.666667
# Kragerud, Rolf        BST         2.857143      2.666667   1.000000
# Overrein, Erik        BST         3.714286      2.000000   4.000000
# Elstad, Ole-Christian BST         3.000000      3.666667   1.333333
# Haavik, Ola           BST         2.285714      2.333333   2.666667
# Oysaed, Jostein       BST         2.000000      1.833333   2.000000
# Viklander, Jonathan   BST         1.428571      2.666667   2.000000
# Strand, Brage         BST         1.285714      1.500000   2.000000
# Angset C., Lise       BST         1.000000      1.000000   1.000000
# Jahren, Kristin       BST         1.000000      1.500000   1.000000
# Landstad, Kari        BST         1.000000      1.833333   2.000000
# Thorne, Wilhelm       BST         1.000000      1.166667   1.000000
# Thylin, Katarina      BST         1.428571      2.500000   1.000000
# Kristensen, Veronica  BST         1.000000      1.333333   1.000000
# Klemsdal, Ragnhild    BST         1.000000      1.000000   1.000000
# Holte, Tormod         ITST        4.428571      2.333333   2.333333
# bg                    ITST        3.857143      2.833333   1.000000
# Alnes, Morten         ITST        4.000000      4.000000   2.000000
# Pedersen, Geir        ITST        4.000000      1.166667   1.333333
# Elverum, Tor          ITST        3.285714      1.500000   1.000000
# Lindberg, Emma        ITST        2.571429      1.666667   1.000000
# Holstad, Mads         ITST        1.571429      2.833333   3.666667
# Hermansen, Thomas     ITST        2.285714      1.000000   1.000000
# Sandstrom, Anton      ITST        1.571429      1.666667   1.666667
# Rode, William         ITST        1.285714      1.000000   1.000000
# Havro, Lars           ITST        1.285714      1.166667   1.333333
# Rystad, Kristina      ITST        2.000000      1.833333   2.000000
# Gussis, Gunnhild      ITST        1.571429      1.666667   1.000000
# Korsen, Eirik Hamre   BST         4.428571      4.000000   1.333333
#
#                             Compliance & andre emner  Business Analytics  \
# Navn                  Team
# Aanonsen, Tor         IM                    3.333333                4.75
# Axelsen, Vebjorn      IM                    3.666667                5.00
# Berisha, Arber        IM                    3.000000                4.50
# Botnen, Martin        IM                    3.666667                2.50
# Ehrndal, Marcus       IM                    4.000000                4.75
# Fladmark, Baste       IM                    2.666667                1.50
# Gaze, Kevin           IM                    3.666667                3.25
# Glaeserud, Pia        IM                    3.333333                4.50
# Henrichsen, Kristian  IM                    3.666667                1.25
# Holmestad, Ola        IM                    3.333333                1.50
# Ivarsoy, Kristine     IM                    2.666667                2.00
# Jorgensen, Morten     IM                    3.666667                1.50
# Krogvig, Lars         IM                    2.666667                2.75
# Larsson, Patrik       IM                    2.666667                1.50
# Lohne, Erik           IM                    3.666667                2.00
# Mortensen, Maria      IM                    2.666667                1.75
# Nygaard, Linn         IM                    4.000000                2.00
# Olsen, Elin           IM                    3.333333                1.25
# Paulsen, Vegar        IM                    4.000000                3.00
# Reidulff, Mari        IM                    2.333333                1.00
# Sunde, Torstein       IM                    3.333333                1.25
# Tokheim, Stian        IM                    3.666667                1.25
# Tveit, Henrik         IM                    2.666667                1.00
# Kragerud, Rolf        BST                   4.333333                1.00
# Overrein, Erik        BST                   4.666667                4.00
# Elstad, Ole-Christian BST                   4.333333                1.75
# Haavik, Ola           BST                   4.000000                2.25
# Oysaed, Jostein       BST                   4.000000                2.50
# Viklander, Jonathan   BST                   3.333333                1.00
# Strand, Brage         BST                   3.000000                1.25
# Angset C., Lise       BST                   2.333333                1.00
# Jahren, Kristin       BST                   3.000000                1.00
# Landstad, Kari        BST                   3.000000                1.00
# Thorne, Wilhelm       BST                   2.666667                1.00
# Thylin, Katarina      BST                   3.333333                1.00
# Kristensen, Veronica  BST                   2.666667                1.00
# Klemsdal, Ragnhild    BST                   3.333333                1.00
# Holte, Tormod         ITST                  3.666667                1.00
# bg                    ITST                  3.000000                1.00
# Alnes, Morten         ITST                  3.666667                2.00
# Pedersen, Geir        ITST                  3.333333                1.50
# Elverum, Tor          ITST                  3.000000                1.00
# Lindberg, Emma        ITST                  3.333333                1.00
# Holstad, Mads         ITST                  3.000000                1.50
# Hermansen, Thomas     ITST                  1.666667                1.25
# Sandstrom, Anton      ITST                  2.333333                1.25
# Rode, William         ITST                  1.000000                1.00
# Havro, Lars           ITST                  1.666667                1.50
# Rystad, Kristina      ITST                  2.333333                1.25
# Gussis, Gunnhild      ITST                  2.666667                1.00
# Korsen, Eirik Hamre   BST                   4.000000                2.00
#
#                             Industri (account perspektiv, TBD)  Ledelse  \
# Navn                  Team
# Aanonsen, Tor         IM                                  2.25      3.0
# Axelsen, Vebjorn      IM                                  2.50      3.6
# Berisha, Arber        IM                                  2.25      2.6
# Botnen, Martin        IM                                  2.50      3.4
# Ehrndal, Marcus       IM                                  2.75      3.6
# Fladmark, Baste       IM                                  2.00      1.8
# Gaze, Kevin           IM                                  1.50      2.0
# Glaeserud, Pia        IM                                  2.25      2.6
# Henrichsen, Kristian  IM                                  2.75      3.4
# Holmestad, Ola        IM                                  2.25      3.0
# Ivarsoy, Kristine     IM                                  1.00      1.2
# Jorgensen, Morten     IM                                  2.25      3.0
# Krogvig, Lars         IM                                  1.25      1.2
# Larsson, Patrik       IM                                  1.75      1.2
# Lohne, Erik           IM                                  2.75      3.6
# Mortensen, Maria      IM                                  1.25      1.2
# Nygaard, Linn         IM                                  1.25      3.0
# Olsen, Elin           IM                                  1.25      2.0
# Paulsen, Vegar        IM                                  3.00      3.8
# Reidulff, Mari        IM                                  1.00      1.2
# Sunde, Torstein       IM                                  1.75      2.0
# Tokheim, Stian        IM                                  1.75      2.8
# Tveit, Henrik         IM                                  1.00      1.4
# Kragerud, Rolf        BST                                 3.25      4.0
# Overrein, Erik        BST                                 2.50      4.2
# Elstad, Ole-Christian BST                                 2.25      3.8
# Haavik, Ola           BST                                 2.75      3.8
# Oysaed, Jostein       BST                                 1.50      4.0
# Viklander, Jonathan   BST                                 1.75      2.0
# Strand, Brage         BST                                 1.75      2.6
# Angset C., Lise       BST                                 1.00      1.8
# Jahren, Kristin       BST                                 1.50      2.2
# Landstad, Kari        BST                                 1.50      2.2
# Thorne, Wilhelm       BST                                 1.75      1.2
# Thylin, Katarina      BST                                 1.50      2.4
# Kristensen, Veronica  BST                                 1.25      1.6
# Klemsdal, Ragnhild    BST                                 1.50      2.0
# Holte, Tormod         ITST                                2.75      3.8
# bg                    ITST                                3.00      3.8
# Alnes, Morten         ITST                                3.50      4.2
# Pedersen, Geir        ITST                                2.50      3.8
# Elverum, Tor          ITST                                2.00      3.4
# Lindberg, Emma        ITST                                2.00      2.2
# Holstad, Mads         ITST                                2.25      2.2
# Hermansen, Thomas     ITST                                1.50      2.2
# Sandstrom, Anton      ITST                                1.50      2.4
# Rode, William         ITST                                1.25      2.2
# Havro, Lars           ITST                                1.50      1.6
# Rystad, Kristina      ITST                                1.75      1.6
# Gussis, Gunnhild      ITST                                2.00      4.0
# Korsen, Eirik Hamre   BST                                 3.00      4.8
#
#                             Change Management  Datavarehus
# Navn                  Team
# Aanonsen, Tor         IM             1.285714     4.000000
# Axelsen, Vebjorn      IM             3.000000     4.333333
# Berisha, Arber        IM             1.142857     3.333333
# Botnen, Martin        IM             2.000000     4.000000
# Ehrndal, Marcus       IM             1.714286     4.000000
# Fladmark, Baste       IM             1.857143     1.666667
# Gaze, Kevin           IM             1.285714     3.333333
# Glaeserud, Pia        IM             1.714286     2.666667
# Henrichsen, Kristian  IM             2.428571     3.333333
# Holmestad, Ola        IM             1.428571     3.666667
# Ivarsoy, Kristine     IM             1.000000     1.666667
# Jorgensen, Morten     IM             2.285714     3.333333
# Krogvig, Lars         IM             1.000000     2.333333
# Larsson, Patrik       IM             1.428571     2.000000
# Lohne, Erik           IM             3.285714     4.333333
# Mortensen, Maria      IM             1.000000     2.000000
# Nygaard, Linn         IM             1.285714     4.333333
# Olsen, Elin           IM             1.000000     2.000000
# Paulsen, Vegar        IM             3.000000     2.666667
# Reidulff, Mari        IM             1.000000     1.000000
# Sunde, Torstein       IM             1.000000     2.666667
# Tokheim, Stian        IM             1.000000     1.666667
# Tveit, Henrik         IM             1.000000     2.000000
# Kragerud, Rolf        BST            3.571429     1.000000
# Overrein, Erik        BST            4.000000     4.000000
# Elstad, Ole-Christian BST            3.000000     1.333333
# Haavik, Ola           BST            3.000000     3.000000
# Oysaed, Jostein       BST            3.000000     2.000000
# Viklander, Jonathan   BST            1.428571     2.000000
# Strand, Brage         BST            1.571429     1.666667
# Angset C., Lise       BST            1.000000     1.000000
# Jahren, Kristin       BST            1.428571     1.000000
# Landstad, Kari        BST            1.000000     1.666667
# Thorne, Wilhelm       BST            1.000000     1.000000
# Thylin, Katarina      BST            1.571429     1.000000
# Kristensen, Veronica  BST            1.285714     1.000000
# Klemsdal, Ragnhild    BST            1.000000     1.000000
# Holte, Tormod         ITST           3.000000     1.000000
# bg                    ITST           5.000000     1.000000
# Alnes, Morten         ITST           4.000000     2.000000
# Pedersen, Geir        ITST           2.000000     1.000000
# Elverum, Tor          ITST           2.000000     1.000000
# Lindberg, Emma        ITST           1.428571     1.333333
# Holstad, Mads         ITST           1.428571     2.000000
# Hermansen, Thomas     ITST           1.571429     1.000000
# Sandstrom, Anton      ITST           1.428571     1.333333
# Rode, William         ITST           1.142857     1.000000
# Havro, Lars           ITST           1.142857     1.000000
# Rystad, Kristina      ITST           1.285714     1.000000
# Gussis, Gunnhild      ITST           5.000000     1.000000
# Korsen, Eirik Hamre   BST            2.714286     1.666667
#
# [51 rows x 22 columns]

# %% [markdown]
# ### KMeans-clustering

# %%
from sklearn.cluster import KMeans

cluster_df = pd.concat([pd.DataFrame(newdf[0]), pd.DataFrame(newdf[1])], axis=1)
kmeans = KMeans(init='k-means++', n_clusters=n_clusters, n_init=10)
kmeans.fit(cluster_df)

# Step size of the mesh. Decrease to increase the quality of the VQ.
h = .02     # point in the mesh [x_min, m_max]x[y_min, y_max].

# Plot the decision boundary. For that, we will assign a color to each
x_min, x_max = cluster_df[0].min() - 1,cluster_df[0].max() + 1
y_min, y_max = cluster_df[1].min() - 1, cluster_df[1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
# Obtain labels for each point in mesh. Use last trained model.
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)

plt.figure(figsize=(30,15))
plt.clf()
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap='Spectral',
           aspect='auto', origin='lower')


# Plot the centroids as a white X
#centroids = kmeans.cluster_centers_
#plt.scatter(centroids[:,0], centroids[:,1],
#            marker='x', s=20, linewidths=3,
#            color='w', zorder=10)

plt.title('K-means clustering over %s med %d clusters' % (type, n_clusters))


cluster_df = pd.concat([df.reset_index()[['Navn', 'Team']], cluster_df], axis=1, ignore_index=True)
cluster_df.columns=['Navn','Team',0,1]

ax = plt.plot(cluster_df[cluster_df['Team']=='IM'][0], cluster_df[cluster_df['Team']=='IM'][1], 'k.', markersize=20,color='b')
plt.plot(cluster_df[cluster_df['Team']=='BST'][0], cluster_df[cluster_df['Team']=='BST'][1], 'k.', markersize=20,color='r')
plt.plot(cluster_df[cluster_df['Team']=='ITST'][0], cluster_df[cluster_df['Team']=='ITST'][1], 'k.', markersize=20,color='g')

#ax = df[df['Team']=='IM'].plot(kind='scatter', x=0, y=1, s=ms, color='Turquoise', label='IM', figsize=(12,12))
#df[df['Team']=='BST' ].plot(kind='scatter', x=0, y=1, s=ms, color='Gold', label='BST', ax=ax)
#df[df['Team']=='ITST'].plot(kind='scatter', x=0, y=1, s=ms, color='Red', label='ITST', ax=ax)

for navn, team, x, y in cluster_df.values:
    if team == 'IM':
        color = 'b'
    elif team == 'BST':
        color = 'r'
    else:
        color='g'
    shortname = re.match('([A-Za-z]+)\,?', navn).group(1)
    plt.annotate(shortname, xy=(x, y), textcoords = 'offset points', xytext = (0,8), size=18, color=color)

plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ### Affinity propagation clustering

# %%
##############################################################################
# Compute Affinity Propagation
cluster_df = pd.concat([pd.DataFrame(newdf[0]), pd.DataFrame(newdf[1])], axis=1)
X=cluster_df.as_matrix()

af = AffinityPropagation().fit(X)
cluster_centers_indices = af.cluster_centers_indices_
labels = af.labels_

n_clusters_ = len(cluster_centers_indices)

##############################################################################
# Plot result

plt.close('all')
plt.figure(figsize=(20,10))
plt.clf()

colors = cycle('rgcmykb')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X[cluster_centers_indices[k]]
    plt.plot(X[class_members, 0], X[class_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    for x in X[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col, linewidth=2.0)

plt.title('Affinity Propagation clustering for %s med %d cluster' % (type,n_clusters_))

cluster_df = pd.concat([df.reset_index()[['Navn', 'Team']], cluster_df], axis=1, ignore_index=True)
cluster_df.columns=['Navn','Team',0,1]

ax = plt.plot(cluster_df[cluster_df['Team']=='IM'][0], cluster_df[cluster_df['Team']=='IM'][1], 'k.', markersize=20,color='b')
plt.plot(cluster_df[cluster_df['Team']=='BST'][0], cluster_df[cluster_df['Team']=='BST'][1], 'k.', markersize=20,color='r')
plt.plot(cluster_df[cluster_df['Team']=='ITST'][0], cluster_df[cluster_df['Team']=='ITST'][1], 'k.', markersize=20,color='g')

for navn, team, x, y in cluster_df.values:
    if team == 'IM':
        color = 'b'
        horz='right'
    elif team == 'BST':
        color = 'r'
        horz='left'
    else:
        color='g'
        horz='center'
    shortname = re.match('([A-Za-z]+)\,?', navn).group(1)
    plt.annotate(shortname, xy=(x, y), textcoords = 'offset points', xytext = (0,8), size=10, color=color, ha=horz)
    
plt.xticks(())
plt.yticks(())
plt.show()
